csv", usecols=columns)
print("Contents in csv file: \n", df)
df.set_index('alpha').plot()
plt.show()
# Out:
# Contents in csv file:
#                       alpha       AUC        AP        HR
# 0                        0  0.583302  0.710959  0.491952
# 1                      0.1  0.602429  0.731248  0.475548
# 2                      0.2  0.662415  0.758224  0.367905
# 3                      0.3  0.576541  0.715844  0.330643
# 4                      0.4  0.529693  0.684270  0.473690
# 5                      0.5  0.535438  0.667346  0.132262
# 6                      0.6  0.559246  0.702235  0.349381
# 7                      0.7  0.654071  0.757532  0.564190
# 8                      0.8  0.549344  0.683641  0.525381
# 9                      0.9  0.613749  0.729991  0.325738
# 10                       1  0.546282  0.682477  0.428119
# 11  no masking in training  0.672880  0.761000  0.589000

# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns = ["alpha", "AUC", "AP", "HR"]
df = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/citeseer_single.csv", usecols=columns)
print("Contents in csv file: \n", df)
df.set_index('alpha').plot()
plt.show()
# Out:
# Contents in csv file:
#      alpha      AUC        AP     HR
# 0     0.0  0.82400  0.829175  0.900
# 1     0.1  0.88590  0.886658  0.925
# 2     0.2  0.89080  0.910014  1.000
# 3     0.3  0.86900  0.878764  0.925
# 4     0.4  0.86800  0.854216  0.900
# 5     0.5  0.83570  0.836071  0.850
# 6     0.6  0.85030  0.856114  0.950
# 7     0.7  0.85710  0.873569  1.000
# 8     0.8  0.85750  0.863853  0.950
# 9     0.9  0.81870  0.814152  0.875
# 10    1.0  0.79865  0.791003  0.925

# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns = ["alpha", "AUC", "AP", "HR"]
df = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/citeseer_multi.csv", usecols=columns)
print("Contents in csv file: \n", df)
df.set_index('alpha').plot()
plt.show()
# Out:
# Contents in csv file:
#      alpha       AUC        AP        HR
# 0     0.0  0.674388  0.766797  0.531872
# 1     0.1  0.789589  0.844945  0.624864
# 2     0.2  0.762830  0.827742  0.640749
# 3     0.3  0.709730  0.794803  0.408182
# 4     0.4  0.717391  0.804809  0.532721
# 5     0.5  0.669370  0.759516  0.589275
# 6     0.6  0.754442  0.813657  0.527917
# 7     0.7  0.685355  0.764596  0.590190
# 8     0.8  0.546009  0.680755  0.476619
# 9     0.9  0.706897  0.781819  0.587390
# 10    1.0  0.592266  0.699078  0.442619

# %%
print("Feature Prediction results")
# Out:
# Feature Prediction results

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/feat_pred.csv")
datasets = df['Datasets'].values
x = np.arange(len(datasets))
w = 0.3
print("with NN as feature encoder: \n", df)
plt.bar(x-w, df['AUC'].values, width=w, label='AUC')
plt.bar(x, df['AP'].values, width=w, label='AP')
plt.bar(x+w, df['HR'].values, width=w, label='HR')
plt.xticks(x, datasets)
plt.ylim([0,1])
plt.tight_layout()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
plt.savefig("CSVBarplots.png", bbox_inches="tight")
plt.show()
# Out:
# with NN as feature encoder:
#     Datasets     AUC  Accuracy     AP  Precision  Recall     HR
# 0  Cora-GAT  0.5150     0.491  0.548      0.202   0.180  0.202
# 1  Cora-GCN  0.4680     0.487  0.520      0.428   0.079  0.428
# 2   ACM-GAT  0.4700     0.498  0.489      0.010   0.000  0.010
# 3   ACM-GCN  0.4680     0.500  0.487      0.000   0.000  0.000
# 4  IMDb-GAT  0.5122     0.492  0.535      0.490   0.100  0.489
# 5  IMDb-GCN  0.4845     0.493  0.536      0.339   0.286  0.339

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/feat_pred_weighted.csv")
datasets = df['Datasets'].values
x = np.arange(len(datasets))
w = 0.3
print("without feature encoder: \n", df)
plt.bar(x-w, df['AUC'].values, width=w, label='AUC')
plt.bar(x, df['AP'].values, width=w, label='AP')
plt.bar(x+w, df['HR'].values, width=w, label='HR')
plt.xticks(x, datasets)
plt.ylim([0,1])
plt.tight_layout()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
plt.savefig("CSVBarplots.png", bbox_inches="tight")
plt.show()
# Out:
# without feature encoder:
#     Datasets       AUC  Accuracy        AP  Precision    Recall        HR
# 0  Cora-GAT  0.473711  0.484063  0.536843   0.483055  0.178125  0.470167
# 1  Cora-GCN  0.524727  0.568438  0.608416   0.726131  0.245000  0.728141
# 2   ACM-GAT  0.539744  0.518947  0.562141   0.652172  0.097895  0.652172
# 3   ACM-GCN  0.473255  0.500000  0.510996   0.000000  0.000000  0.000000
# 4  IMDb-GAT  0.473388  0.456364  0.504151   0.404382  0.145909  0.406655
# 5  IMDb-GCN  0.484500  0.493000  0.536000   0.339000  0.286000  0.339000

# %%
print("different type of loss functions:")
print("1: loss = loss_A + loss_F")
print("2: loss = (1/#ones in A) * loss_A + (1/#ones in F) * loss_F")
print("3: loss = (#ones in F/#ones in A) * loss_A + (#ones in A/#ones in F) * loss_F")
print("4: loss = 1/n^2 * loss_A + 1/n*d * loss_F")
print("5: loss = loss_F")
print("6: loss = (#ones in A/#ones in F) * loss_A + (#ones in F/#ones in A) * loss_F")
print("\n\n")

import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns = ["epochs", "1", "2", "3","4","5","6","7","8"]
df = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/loss_f/feat_pred - cora.csv", usecols=columns)
print("Contents in csv file: \n", df)
df.set_index('epochs').plot()
plt.show()
# Out:
# different type of loss functions:
# 1: loss = loss_A + loss_F
# 2: loss = (1/#ones in A) * loss_A + (1/#ones in F) * loss_F
# 3: loss = (#ones in F/#ones in A) * loss_A + (#ones in A/#ones in F) * loss_F
# 4: loss = 1/n^2 * loss_A + 1/n*d * loss_F
# 5: loss = loss_F
# 6: loss = (#ones in A/#ones in F) * loss_A + (#ones in F/#ones in A) * loss_F
#
#
#
# Contents in csv file:
#      epochs         1         2         3         4         5         6  \
# 0        1  0.694845  0.694845  0.694845  0.694845  0.694845  0.694845
# 1        2  0.685935  0.702140  0.686932  0.703840  0.687935  0.684577
# 2        3  0.651552  0.735229  0.665428  0.751508  0.634462  0.587839
# 3        4  0.593891  0.782104  0.630490  0.824196  0.630281  0.618122
# 4        5  0.559643  0.801444  0.592065  0.854950  0.617697  0.554797
# ..     ...       ...       ...       ...       ...       ...       ...
# 95      96  0.173778  0.635385  0.300943  0.729237  0.157966  0.071568
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns = ["epochs", "1", "2", "3","4","5","6","7","8"]
df = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/loss_f/feat_pred - ACM.csv", usecols=columns)
print("Contents in csv file: \n", df)
df.set_index('epochs').plot()
plt.show()
# Out:
# Contents in csv file:
#      epochs         1         2         3         4         5         6  \
# 0        1  0.697384  0.697384  0.697384  0.697384  0.697384  0.697384
# 1        2  0.741483  0.799171  0.739996  0.799549  0.767948  0.782738
# 2        3  0.683332  0.889441  0.736401  0.896219  0.714613  0.705997
# 3        4  0.630098  0.876225  0.685262  0.896874  0.624873  0.612649
# 4        5  0.604483  0.867539  0.634647  0.889957  0.596207  0.570883
# ..     ...       ...       ...       ...       ...       ...       ...
# 95      96  0.413772  0.719353  0.483070  0.733297  0.422261  0.348000
# 96      97  0.410536  0.719132  0.482094  0.733157  0.420601  0.345777
# 97      98  0.407792  0.719268  0.482428  0.733404  0.418869  0.343567
# 98      99  0.408229  0.719099  0.481577  0.733317  0.417455  0.341367
# 99     100  0.411166  0.719487  0.481314  0.733658  0.416330  0.339263
#
#            7         8
# 0   0.697384  0.697384
# 1   0.746456  0.739979
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns = ["epochs", "1", "2", "3","4","5","6","7","8"]
df = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/loss_f/feat_pred - IMDB.csv", usecols=columns)
print("Contents in csv file: \n", df)
df.set_index('epochs').plot()
plt.show()
# Out:
# Contents in csv file:
#      epochs         1         2         3         4         5         6  \
# 0        1  0.694378  0.694378  0.694378  0.694378  0.694378  0.694378
# 1        2  0.684804  0.698598  0.684807  0.699784  0.685089  0.684179
# 2        3  0.662941  0.727388  0.664450  0.735479  0.656606  0.657450
# 3        4  0.630647  0.766486  0.635156  0.787152  0.640002  0.618866
# 4        5  0.600421  0.790319  0.605084  0.820249  0.622977  0.601364
# ..     ...       ...       ...       ...       ...       ...       ...
# 95      96  0.050735  0.659899  0.103781  0.732732  0.023852  0.025449
# 96      97  0.050131  0.659124  0.102413  0.734121  0.023994  0.025206
# 97      98  0.049600  0.658660  0.101039  0.732860  0.023715  0.025093
# 98      99  0.048905  0.659402  0.099870  0.733774  0.023432  0.024741
# 99     100  0.048511  0.659006  0.098747  0.733005  0.023131  0.024528
#
#            7         8
# 0   0.694378  0.694378
# 1   0.682388  0.684908
# ...

# %%
print("observing loss_f during training:\n\n")

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/loss_type/feat_pred - loss_type
# %%
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/latent_dim/latent_dim_cora.csv")
datasets = df['Datasets'].values
x = np.arange(len(datasets))
w = 0.2
print("with NN as feature encoder: \n", df)
plt.bar(x-w, df['AUC'].values, width=w, label='AUC')
plt.bar(x, df['AP'].values, width=w, label='AP')
plt.bar(x+w, df['HR'].values, width=w, label='HR')
plt.xticks(x, datasets)
plt.ylim([0,1])
plt.tight_layout()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
plt.savefig("CSVBarplots.png", bbox_inches="tight")
plt.show()
# Out:
# with NN as feature encoder:
#          Datasets       AUC  Accuracy        AP  Precision    Recall        HR
# 0   cora_128_adj  0.892400  0.490000  0.767112   0.000000  0.000000  0.000000
# 1  cora_128_feat  0.905195  0.821875  0.882934   0.905732  0.724375  0.900769
# 2   cora_256_adj  0.918200  0.485000  0.835138   0.000000  0.000000  0.000000
# 3  cora_256_feat  0.910977  0.803750  0.892862   0.899613  0.689375  0.913846
# 4   cora_512_adj  0.859900  0.485000  0.718185   0.000000  0.000000  0.000000
# 5  cora_512_feat  0.850547  0.710313  0.838567   0.835969  0.534375  0.899231

# %%
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/latent_dim/latent_dim_ACM.csv")
datasets = df['Datasets'].values
x = np.arange(len(datasets))
w = 0.2
print("with NN as feature encoder: \n", df)
plt.bar(x-w, df['AUC'].values, width=w, label='AUC')
plt.bar(x, df['AP'].values, width=w, label='AP')
plt.bar(x+w, df['HR'].values, width=w, label='HR')
plt.xticks(x, datasets)
plt.ylim([0,1])
plt.tight_layout()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
plt.savefig("CSVBarplots.png", bbox_inches="tight")
plt.show()
# Out:
# with NN as feature encoder:
#         Datasets       AUC  Accuracy        AP  Precision    Recall        HR
# 0   ACM_128_adj  0.130000  0.490000  0.335209   0.000000  0.000000  0.000000
# 1  ACM_128_feat  0.809557  0.564868  0.843553   0.984452  0.132368  0.984452
# 2   ACM_256_adj  0.067000  0.485000  0.321790   0.000000  0.000000  0.000000
# 3  ACM_256_feat  0.826780  0.602895  0.851166   0.984000  0.209737  0.984000
# 4   ACM_512_adj  0.033500  0.470000  0.314814   0.000000  0.000000  0.000000
# 5  ACM_512_feat  0.817770  0.674211  0.846967   0.935978  0.376053  0.937272

# %%
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/latent_dim/latent_dim_IMDB.csv")
datasets = df['Datasets'].values
x = np.arange(len(datasets))
w = 0.2
print("with NN as feature encoder: \n", df)
plt.bar(x-w, df['AUC'].values, width=w, label='AUC')
plt.bar(x, df['AP'].values, width=w, label='AP')
plt.bar(x+w, df['HR'].values, width=w, label='HR')
plt.xticks(x, datasets)
plt.ylim([0,1])
plt.tight_layout()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
plt.savefig("CSVBarplots.png", bbox_inches="tight")
plt.show()
# Out:
# with NN as feature encoder:
#          Datasets       AUC  Accuracy        AP  Precision    Recall        HR
# 0   IMDB_128_adj  0.969600  0.495000  0.899756   0.000000  0.000000  0.000000
# 1  IMDB_128_feat  0.904256  0.612273  0.904926   0.998333  0.225000  0.998333
# 2   IMDB_256_adj  0.990100  0.995000  0.963027   0.990099  1.000000  0.975000
# 3  IMDB_256_feat  0.905393  0.633409  0.912228   0.994226  0.268636  0.994226
# 4   IMDB_512_adj  0.870800  0.495000  0.733838   0.000000  0.000000  0.000000
# 5  IMDB_512_feat  0.894483  0.608636  0.897896   0.990893  0.220000  0.990893

# %% [markdown]
# Comparing loss functions with hyperparameters and without hyperparameters:
#
# 1: loss = loss_A + loss_F
#
# 7: loss = (n*d)/(n*n) * loss_A + (n*n/n*d) * loss_F
#
# 1_hp: loss = lambda_1 * loss_A + lambda_1 * loss_F
#
# 7_hp: lambda_1 * (n*d)/(n*n) * loss_A + lambda_2 * (n*n/n*d) * loss_F

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/loss_type/feat_pred_hp - feat_pred_cora.csv")
datasets = df['Datasets'].values
x = np.arange(len(datasets))
w = 0.2
print("with NN as feature encoder: \n", df)
plt.bar(x-w, df['AUC'].values, width=w, label='AUC')
plt.bar(x, df['AP'].values, width=w, label='AP')
plt.bar(x+w, df['HR'].values, width=w, label='HR')
plt.xticks(x, datasets)
plt.ylim([0,1])
plt.tight_layout()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
plt.savefig("CSVBarplots.png", bbox_inches="tight")
plt.show()

df2 = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/loss_type/feat_pred_hp - link_pred_cora.csv")
datasets2 = df2['Datasets'].values
x = np.arange(len(datasets))
w = 0.2
print("with NN as feature encoder: \n", df2)
plt.bar(x-w, df2['AUC'].values, width=w, label='AUC')
plt.bar(x, df2['AP'].values, width=w, label='AP')
plt.bar(x+w, df2['HR'].values, width=w, label='HR')
plt.xticks(x, datasets2)
plt.ylim([0,1])
plt.tight_layout()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
plt.savefig("CSVBarplots.png", bbox_inches="tight")
plt.show()
# Out:
# with NN as feature encoder:
#      Datasets       AUC  Accuracy        AP  Precision    Recall        HR
# 0  cora_1_hp  0.893594  0.722812  0.867361   0.888569  0.515625  0.883462
# 1  cora_7_hp  0.798906  0.618125  0.793746   0.850237  0.298125  0.844756
# 2     cora_1  0.905195  0.821875  0.882934   0.905732  0.724375  0.900769
# 3     cora_7  0.882695  0.747812  0.852115   0.866759  0.594375  0.893846
# with NN as feature encoder:
#      Datasets     AUC  Accuracy        AP  Precision  Recall     HR
# 0  cora_1_hp  0.9600      0.48  0.874277   0.000000       0  0.000
# 1  cora_7_hp  0.9900      0.98  0.958041   0.961538       1  0.975
# 2     cora_1  0.8924      0.49  0.767112   0.000000       0  0.000
# 3     cora_7  0.9800      0.99  0.925858   0.980392       1  0.950

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/loss_type/feat_pred_hp - feat_pred_ACM.csv")
datasets = df['Datasets'].values
x = np.arange(len(datasets))
w = 0.2
print("with NN as feature encoder: \n", df)
plt.bar(x-w, df['AUC'].values, width=w, label='AUC')
plt.bar(x, df['AP'].values, width=w, label='AP')
plt.bar(x+w, df['HR'].values, width=w, label='HR')
plt.xticks(x, datasets)
plt.ylim([0,1])
plt.tight_layout()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
plt.savefig("CSVBarplots.png", bbox_inches="tight")
plt.show()

df2 = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/loss_type/feat_pred_hp - link_pred_ACM.csv")
datasets2 = df2['Datasets'].values
x = np.arange(len(datasets))
w = 0.2
print("with NN as feature encoder: \n", df2)
plt.bar(x-w, df2['AUC'].values, width=w, label='AUC')
plt.bar(x, df2['AP'].values, width=w, label='AP')
plt.bar(x+w, df2['HR'].values, width=w, label='HR')
plt.xticks(x, datasets2)
plt.ylim([0,1])
plt.tight_layout()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
plt.savefig("CSVBarplots.png", bbox_inches="tight")
plt.show()
# Out:
# with NN as feature encoder:
#     Datasets       AUC  Accuracy        AP  Precision    Recall        HR
# 0  ACM_1_hp  0.407971  0.431711  0.438837   0.399756  0.255789  0.303548
# 1  ACM_7_hp  0.673283  0.607368  0.722767   0.659307  0.457632  0.862903
# 2     ACM_1  0.809557  0.564868  0.843553   0.984452  0.132368  0.984452
# 3     ACM_7  0.802694  0.551053  0.840599   1.000000  0.102105  1.000000
# with NN as feature encoder:
#     Datasets     AUC  Accuracy        AP  Precision  Recall  HR
# 0  ACM_1_hp  0.2300     0.495  0.457707          0       0   0
# 1  ACM_7_hp  1.0000     1.000  1.000000          1       1   1
# 2     ACM_1  0.1300     0.490  0.335209          0       0   0
# 3     ACM_7  0.5128     0.490  0.459098          0       0   0

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/loss_type/feat_pred_hp - feat_pred_IMDB.csv")
datasets = df['Datasets'].values
x = np.arange(len(datasets))
w = 0.2
print("with NN as feature encoder: \n", df)
plt.bar(x-w, df['AUC'].values, width=w, label='AUC')
plt.bar(x, df['AP'].values, width=w, label='AP')
plt.bar(x+w, df['HR'].values, width=w, label='HR')
plt.xticks(x, datasets)
plt.ylim([0,1])
plt.tight_layout()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
plt.savefig("CSVBarplots.png", bbox_inches="tight")
plt.show()

df2 = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/loss_type/feat_pred_hp - link_pred_IMDB.csv")
datasets2 = df2['Datasets'].values
x = np.arange(len(datasets))
w = 0.2
print("with NN as feature encoder: \n", df2)
plt.bar(x-w, df2['AUC'].values, width=w, label='AUC')
plt.bar(x, df2['AP'].values, width=w, label='AP')
plt.bar(x+w, df2['HR'].values, width=w, label='HR')
plt.xticks(x, datasets2)
plt.ylim([0,1])
plt.tight_layout()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
plt.savefig("CSVBarplots.png", bbox_inches="tight")
plt.show()
# Out:
# with NN as feature encoder:
#      Datasets       AUC  Accuracy        AP  Precision    Recall        HR
# 0  IMDB_1_hp  0.827831  0.620227  0.844755   0.989167  0.244091  0.989167
# 1  IMDB_7_hp  0.733492  0.500000  0.769849   0.000000  0.000000  0.000000
# 2     IMDB_1  0.904256  0.612273  0.904926   0.998333  0.225000  0.998333
# 3     IMDB_7  0.870579  0.575455  0.871762   1.000000  0.150909  1.000000
# with NN as feature encoder:
#      Datasets     AUC  Accuracy        AP  Precision  Recall     HR
# 0  IMDB_1_hp  0.9900     0.995  0.958027   0.990099       1  0.975
# 1  IMDB_7_hp  0.9200     0.470  0.796311   0.000000       0  0.000
# 2     IMDB_1  0.9696     0.495  0.899756   0.000000       0    NaN
# 3     IMDB_7  0.9700     0.495  0.898496   0.000000       0  0.000

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/loss_type/feat_pred_hp - feat_pred_citeseer.csv")
datasets = df['Datasets'].values
x = np.arange(len(datasets))
w = 0.2
print("feature pred: \n", df)
plt.bar(x-w, df['AUC'].values, width=w, label='AUC')
plt.bar(x, df['AP'].values, width=w, label='AP')
plt.bar(x+w, df['HR'].values, width=w, label='HR')
plt.xticks(x, datasets)
plt.ylim([0,1])
plt.tight_layout()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
plt.savefig("CSVBarplots.png", bbox_inches="tight")
plt.show()

df2 = pd.read_csv("/Users/erfanehmahmoudzadeh/Desktop/data/loss_type/feat_pred_hp - link_pred_citeseer.csv")
datasets2 = df2['Datasets'].values
x = np.arange(len(datasets))
w = 0.2
print("link pred: \n", df2)
plt.bar(x-w, df2['AUC'].values, width=w, label='AUC')
plt.bar(x, df2['AP'].values, width=w, label='AP')
plt.bar(x+w, df2['HR'].values, width=w, label='HR')
plt.xticks(x, datasets2)
plt.ylim([0,1])
plt.tight_layout()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
plt.savefig("CSVBarplots.png", bbox_inches="tight")
plt.show()
# Out:
# feature pred:
#          Datasets       AUC  Accuracy        AP  Precision    Recall        HR
# 0  citeseer_1_hp  0.766972  0.544634  0.799714   0.946579  0.095366  0.946579
# 1  citeseer_7_hp  0.782748  0.593537  0.802456   0.913357  0.209024  0.913357
# 2     citeseer_1  0.818275  0.594634  0.835531   0.949769  0.200976  0.949769
# 3     citeseer_7  0.817888  0.590610  0.828204   0.918019  0.200976  0.918019
# link pred:
#          Datasets     AUC  Accuracy        AP  Precision  Recall  HR
# 0  citeseer_1_hp  0.4700     0.490  0.441472          0       0   0
# 1  citeseer_7_hp  0.8607     0.490  0.711570          0       0   0
# 2     citeseer_1  0.6385     0.490  0.523311          0       0   0
# 3     citeseer_7  0.5707     0.495  0.485835          0       0   0

# %%
import pandas as pd
from matplotlib import pyplot as plt

datasets = ["cora", "ACM", "IMDB", "citeseer"]
for d in datasets:
    path = "/Users/erfanehmahmoudzadeh/Desktop/data/loss/feature_pred - loss_"+d+".csv"

    print("################################################################################################\n")
    print(d+":")
    plt.rcParams["figure.figsize"] = [7.00, 3.50]
    plt.rcParams["figure.autolayout"] = True
    columns = ["epochs", "link", "feature"]
    df = pd.read_csv(path, usecols=columns)
    #print("Contents in csv file: \n", df)
    df.set_index('epochs').plot()
    plt.show()
# Out:
# ################################################################################################
#
# cora:
# ################################################################################################
#
# ACM:
# ################################################################################################
#
# IMDB:
# ################################################################################################
#
# citeseer:

# %%
path = "/Users/erfanehmahmoudzadeh/Desktop/data/loss/feature_pred - loss_val.csv"

plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns = ["epochs", "cora", "ACM", "IMDB", "citeseer"]
df = pd.read_csv(path, usecols=columns)
#print("Contents in csv file: \n", df)
df.set_index('epochs').plot()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

datasets = ["cora", "ACM", "IMDB", "citeseer"]
for d in datasets:
    path_feat = "/Users/erfanehmahmoudzadeh/Desktop/data/results/feature_pred - "+d+"_feat.csv"
    path_adj = "/Users/erfanehmahmoudzadeh/Desktop/data/results/feature_pred - "+d+"_adj.csv"

    print("################################################################################################\n")
    print(d+":")
    df = pd.read_csv(path_feat)
    datasets = df['Datasets'].values
    x = np.arange(len(datasets))
    w = 0.2
    print("feature pred: \n", df)
    plt.bar(x-w, df['AUC'].values, width=w, label='AUC')
    plt.bar(x, df['AP'].values, width=w, label='AP')
    plt.bar(x+w, df['HR'].values, width=w, label='HR')
    plt.xticks(x, datasets)
    plt.ylim([0,1])
    plt.tight_layout()
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
    plt.savefig("CSVBarplots.png", bbox_inches="tight")
    plt.show()

    df2 = pd.read_csv(path_adj)
    datasets2 = df2['Datasets'].values
    x = np.arange(len(datasets))
    w = 0.2
    print("link pred: \n", df2)
    plt.bar(x-w, df2['AUC'].values, width=w, label='AUC')
    plt.bar(x, df2['AP'].values, width=w, label='AP')
    plt.bar(x+w, df2['HR'].values, width=w, label='HR')
    plt.xticks(x, datasets2)
    plt.ylim([0,1])
    plt.tight_layout()
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, ncol=5)
    plt.savefig("CSVBarplots.png", bbox_inches="tight")
    plt.show()
# Out:
# ################################################################################################
#
# cora:
# feature pred:
#     Datasets       AUC  Accuracy        AP  Precision    Recall        HR
# 0    cora_1  0.896211  0.781875  0.872314   0.872762  0.670625  0.895385
# 1   cora_10  0.856289  0.654687  0.827060   0.857921  0.379375  0.859231
# 2   cora_50  0.801836  0.674063  0.782549   0.817382  0.458125  0.811987
# 3  cora_100  0.779805  0.553125  0.753007   0.778369  0.167500  0.776295
# link pred:
#     Datasets     AUC  Accuracy        AP  Precision  Recall    HR
# 0    cora_1  0.9800     0.985  0.925858   0.970874    1.00  0.95
# 1   cora_10  0.9700     0.490  0.898496   0.000000    0.00  0.00
# 2   cora_50  0.9798     0.765  0.925667   0.964912    0.55  0.95
# 3  cora_100  0.9200     0.490  0.796311   0.000000    0.00  0.00
# ################################################################################################
#
# ACM:
# feature pred:
# ...
